# %% [markdown]
# # Part 1

# %% [markdown]
# ## A

# %% [markdown]
# $\textit{What is the Oxford English Dictionary's defintion of a narrative?}$

# %% [markdown]
# The Oxford English Dictionary defines narrative as “an account of a
# series of events, facts, etc., given in order and with the establishing of
# connections between them.” Central to this definition is the notion of
# a chain of causally related events. Stories of this form often have a
# beginning, middle, and end [3, 24]: an introduction to the situation, a
# series of events often involving tension or conflict, and a resolution.

# %% [markdown]
# $\textit{What is your favorite visualization among the examples in section 3? Explain why in a few words.}$

# %% [markdown]
# The favorite visualization among the examples in section 3 is Gapminder Human Development Trends, figure 4. It seems to be the figure that best align with the visual narative techniques presented in section 2 and thus the most describtive and clear in its message.
# It has a clear starting point which esthablish an overview of the different elements analyzed in the report. This is enriched by the use of bright colors and by the viewers task by top-down search clearly shows what to do next after have seen the overview by the "Start" button in the right corner. By using the same color for the different regions, semantically consisten bewteen slides and chaning the chart types for every section makes it very clear for the viewer in order to avoid any confusion.
# It also have a clear narative structure with a beginning(overview)-middle(different sections) and end (Clear message that with current trends Africa and Latin America will not meet the goal).

# %% [markdown]
# $\textit{What's the point of Figure 7?}$

# %% [markdown]
# Figure 7 is an analysis of 58 visualizations using the case study method illustrated in section 3 of the paper. It was used to find emerging patterns of narative visualizations techniques. This was done by first dividing the design space into three divisions of features that is further divided into sub sections. They found 3 important points that stand out from the data. (1) Clustering of different odering structures, (2) the consistency of interaction design, and (3) ther under-utilization of narrative messaging.

# %% [markdown]
# $\textit{Use Figure 7 to find the most common design choice within each category for the Visual narrative and Narrative structure (the categories within visual narrative are 'visual structuring', 'highlighting', etc).}$

# %% [markdown]
# $\textbf{Visual Structuring:}$
# Consisten Visual Platform (34), Esthablishing shot (21), Progress Bar (19), Checklist (9)
#
# $\textbf{Highlighting:}$
# Feature Distinction (46), Motion (18), Closeups (13), Zooming (10), Character Direction (6), Audio (3)
#
# $\textbf{Transition Guidance:}$
# Object Continuity (22), Animated transitions (20), Familiar Object (17), Viewer motion (8), Continuity Editing (3), Viewing angle (3)
#
# $\textbf{Ordering:}$
# User Direction Path (31), Linear (19), Random Acces (7)
#
# $\textbf{Interactivity:}$
# Filtering (43), Very limited interactivity (35), Hover Highlighting (34), Explicit Instructions (31), Navigation Button (22), Stimulating default views (15), Tacit Turorial (6)
#
# $\textbf{Messaging:}$
# Captions (49), Annotations (37), Introductory text (27), Multi Messaging (26),Comment Repitition (13), Accompanying article (12), Summary (6)

# %% [markdown]
# $\textit{Check out Figure 8 and section 4.3. What is your favorite genre of narrative visualization? Why? What is your least favorite genre? Why?}$

# %% [markdown]
# Of the seven genres presented in figure 8 the gavorite genre of the visualization must be the annotated chart. There is just something beautiful about being able to illustrate ones message with a simple and elegant graph. It is a method in which ones point can be illustrated scientifically in a very simple and clear manner. Trends in the graph can clearly be observed and pointed out with annotation.
# From last assignment it was also discussed the vision is a great tool for data analysis and thus the best way to encode data. However one always have to avoid making it to much of a cluster.

# %% [markdown]
# ## B

# %% [markdown]
# $\textit{What are the three key elements to keep in mind when you design an explanatory visualization?}$

# %% [markdown]
# The three key points:
#
#     Start with a question (what is the result you want to communicate?)
#
#     Allow exploration (Let the users investigate)
#
#     Know your readers (design for an audience)

# %% [markdown]
# $\textit{In the video I talk about (1) overview first, (2) zoom and filter, (3) details on demand.
# Go online and find a visualization that follows these principles (don't use one from the video).
# Explain how it does achieves (1)-(3). It might be useful to use screenshots to illustrate your explanation.}$

# %% [markdown]
# A visualization from The Berliner Morgenpost's have been found, can be seen [here](Thttps://interaktiv.morgenpost.de/europakarte/#4/48.92/18.54/en) or sreenshot below.
# The visualization give a quick overview over the population growth of Europe with a color code. It is then possible to filter the information with the tabs in the bottom of the page to show different data such as birth rate, see screenshot below. If you hower over the map is shows details on demand by showing the city, its population and its annualy increase. The data visualization is thus following the three principils Sune is talking about in his video.

# %% [markdown]
# ![image.png](attachment:image.png)*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\textit{Explain in your own words: How is explanatory data analysis different from exploratory data analysis?}$

# %% [markdown]
# Exploratory analysis is the initial step in data analysis. It usually consist of getting to know the data by simple statistics and data visuliazation to use the human eye to find patterns in the data. Finding trends, correlations and outliers. Exploratory analysis is often the preperation for further in depth research since the initial analysis hopefully shows interesting trends/patterns as a base for further research. It explores the data.
#
# Explanatory analysis seeks to explain the findings from exploratory by answering "why" and "how". It is thus a more in depth analysis of patterns discovered. It is what happens when you have something specific you want to show an audience, in other words, when you want to tell a story with data. Thus this is where the narative visualizations techniques and structure is imporant in order to communicate your message.
